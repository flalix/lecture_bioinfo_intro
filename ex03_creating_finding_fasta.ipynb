# %% [markdown]
# ## Abrindo bibliotecas

# %%
import copy, os, sys, re
import numpy as np
from IPython.display import Image, display

from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
root0 = 'drive/MyDrive'

# %%
root_aula = 'Colab Notebooks/aulas/seqs_fasta_202504'
root_data = os.path.join(root0, root_aula)
os.listdir(root_data)
# Out:
# ['ex01_python.ipynb',
#  'images',
#  'fasta',
#  'ex02_sharing_a_drive.ipynb',
#  'ex03_reading_fasta.ipynb']

# %%
root_imagens = os.path.join(root_data, 'images')
root_fastas = os.path.join(root_data, 'fasta')

print(root_imagens)
print(root_fastas)
# Out:
# drive/MyDrive/Colab Notebooks/aulas/seqs_fasta_202504/images
# drive/MyDrive/Colab Notebooks/aulas/seqs_fasta_202504/fasta

# %% [markdown]
# ## Abrindo Biopython: algum problema?

# %%
from Bio import SeqIO
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-5d24a7c49c42> in <cell line: 0>()
# ----> 1 from Bio import SeqIO
#
# ModuleNotFoundError: No module named 'Bio'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# ### Caso a biblioteca não existe, temos que instalá-la

# %%
# !pip install biopython
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 64.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Abrindos as bibliotecas BioPython e matplotlib (gráficos)

# %%
from Bio import SeqIO
from Bio.Seq import Seq
from Bio.SeqRecord import SeqRecord

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
# %matplotlib inline

# %% [markdown]
# ## Construindo suas próprias funções

# %%
def getDnaNucleotides():
    return ['A','T','G','C']

def getDnaNucleotideString():
    return 'ATGC'

def getRnaNucleotides():
    return ['A','U','G','C']

def getSeqAA():
    return ['A', 'M', 'C', 'F', 'L', 'V', 'I', 'G', 'T', 'S', 'W', 'Y', 'P', 'H', 'N', 'D', 'E', 'Q', 'K', 'R']

def getAaPos(string, aa):
    return string.find(aa)

# %%
getDnaNucleotides()
# Out:
# ['A', 'T', 'G', 'C']

# %%
lista = getDnaNucleotides()
lista
# Out:
# ['A', 'T', 'G', 'C']

# %%
# pegar cada nucleotídeo
for nuc in lista:
  print(nuc)
# Out:
# A
# T
# G
# C

# %% [markdown]
# ## Entrar no NCBI
#
# https://www.ncbi.nlm.nih.gov/

# %% [markdown]
# ### Procurar a base nucleotide
#
# https://www.ncbi.nlm.nih.gov/nuccore/

# %% [markdown]
# ### Procurar o gene COX2

# %%
image_path = 'drive/MyDrive/Colab Notebooks/aulas/seqs_fasta_202504/images/cox2_nucleotide_ncbi.png'
display(Image(image_path))

# %% [markdown]
# ### Query (indagar a base)
#
# ((200:1000[Sequence Length]) AND (((COX2) AND "Homo sapiens"[porgn:__txid9606]))

# %% [markdown]
# ### Baixando sequencias de nucleotideos (DNA)

# %%
image_path = 'drive/MyDrive/Colab Notebooks/aulas/seqs_fasta_202504/images/baixar_nucleotideos.png'
display(Image(image_path))

# %% [markdown]
# ### Baixando sequencias de amino ácidos (Proteina)

# %%
image_path = 'drive/MyDrive/Colab Notebooks/aulas/seqs_fasta_202504/images/baixar_aminoacidos.png'
display(Image(image_path))

# %% [markdown]
# ### Alinhar sequências
#
#   - NCBI: https://www.ncbi.nlm.nih.gov/projects/msaviewer/
#     - Data File: upload
#   - Clustal Omega
#     - https://www.ebi.ac.uk/jdispatcher/msa/clustalo

# %% [markdown]
# ### Baixar o Seaview
#
# https://doua.prabi.fr/software/seaview

# %% [markdown]
# ## Alinhar com Seaview

# %% [markdown]
# ### O arquivo existe?
#
#   - seqs DNA: cox2_dna_aligned.fasta
#   - seqs Proteina: cox2_protein_aligned.fasta

# %%
fname = 'cox2_dna_aligned.fasta'
os.path.exists(fname), fname
# Out:
# (False, 'cox2_dna_aligned.fasta')

# %% [markdown]
# ### Porque não existe?
#   - Faltou a rota (path)

# %%
root_fastas
# Out:
# 'drive/MyDrive/Colab Notebooks/aulas/seqs_fasta_202504/fasta'

# %%
os.listdir(root_fastas)
# Out:
# ['cox2_protein.fasta',
#  'cox2_dna.fasta',
#  'cox2_protein_aligned.fasta',
#  'cox2_dna_aligned.fasta']

# %% [markdown]
# ## Arquivo de DNA ok?

# %%
fname = 'cox2_protein_aligned.fasta'
filename = os.path.join(root_fastas, fname)

os.path.exists(filename), filename
# Out:
# (True,
#  'drive/MyDrive/Colab Notebooks/aulas/seqs_fasta_202504/fasta/cox2_protein_aligned.fasta')
