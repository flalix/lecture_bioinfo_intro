# %% [markdown]
# ## Abrindo bibliotecas

# %%
import copy, os, sys, re

# %% [markdown]
# ### Acessando 'meu' google drive

# %%
from google.colab import drive

# %% [markdown]
# ### Montando o drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Dados em drive/MyDrive (padrão Google)

# %%
root0 = 'drive/MyDrive'

# %%
root_aula = 'Colab Notebooks/aulas/seqs_fasta_202504'
root_data = os.path.join(root0, root_aula)
os.listdir(root_data)
# Out:
# ['ex02_sharing_a_drive.ipynb',
#  'images',
#  'fasta',
#  'ex03_reading_fasta.ipynb',
#  'ex01_python.ipynb']

# %% [markdown]
# ## O que tem na pasta 'images'?

# %%
root_imagens = os.path.join(root_data, 'images')
os.listdir(root_imagens)
# Out:
# ['baixar_aminoacidos.png',
#  'cox2_nucleotide_ncbi.png',
#  'baixar_nucleotideos.png']

# %% [markdown]
# ## O que tem na pasta 'fasta'?

# %%
root_fastas = os.path.join(root_data, 'fasta')
os.listdir(root_fastas)
# Out:
# ['cox2_dna.fasta',
#  'cox2_dna_aligned.fasta',
#  'cox2_protein_aligned.fasta',
#  'cox2_protein.fasta']
